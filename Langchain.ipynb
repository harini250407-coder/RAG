# %%
# !pip install -U langchain langchain-community
# !pip install langchain-groq
# !pip install faiss-cpu sentence-transformers tiktoken
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 5.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.7
#     Uninstalling langchain-1.3.7:
#       Successfully uninstalled langchain-1.3.7
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 7.9 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain-classic
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_classic.chains import RetrievalQA
from langchain_groq import ChatGroq
import os
# Out:
# ...
# /tmp/ipykernel_8942/2647081765.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("/content/notes.txt")
documents = loader.load()

# %%
splitter = CharacterTextSplitter(chunk_size=500,chunk_overlap=50)
docs = splitter.split_documents(documents)

# %%
embeddings = HuggingFaceEmbeddings()
vectorstore = FAISS.from_documents(docs,embeddings)
# Out:
# /tmp/ipykernel_8942/1707513960.py:1: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embeddings = HuggingFaceEmbeddings()
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %%
os.environ["GROQ_API_KEY"] = "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"

# %%
llm = ChatGroq(
    groq_api_key=os.environ["GROQ_API_KEY"],
    model_name="llama-3.3-70b-versatile"
)

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=vectorstore.as_retriever()
)

question = "tell me about kedharnath"
result = qa_chain.run(question)

print("Answer:",result)
# Out:
# /tmp/ipykernel_8942/845952980.py:7: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain-classic 0.1.0 and will be removed in 2.0.0. Use `invoke` instead.
#   result = qa_chain.run(question)
# Answer: Kedarnath is a highly revered Hindu pilgrimage town located in the Garhwal Himalayas of Uttarakhand, India. It is situated at an altitude of 3,586 meters (11,755 feet) near the head of the Mandakini River in the Rudraprayag district.
#
# The town is famous for its ancient 8th-century stone temple dedicated to Lord Shiva, which is one of the 12 Jyotirlingas and a key stop on the sacred Char Dham yatra. According to Hindu legends, the temple was built by the Pandava brothers to atone for their sins after the Mahabharata war. The self-manifested Shiva Linga is believed to represent the hump of a bull, the form Lord Shiva took when the Pandavas tried to find him.
#
# ...
